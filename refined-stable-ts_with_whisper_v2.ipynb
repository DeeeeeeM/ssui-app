# %%
import stable_whisper

audio_file = 'C:\\Users\\HEIDEL\\Desktop\\PS_112225_FULL\\PS_112225_FULL.mp4'
prompt = "This recording discusses Philippine cuisine, food culture, and culinary history. The conversation may be in Tagalog and English (Taglish) and may include regional terms from Kapampangan, Ilocano, and Visayan languages. It may mention traditional dishes such as adobo, sinigang, kare-kare, sisig, lechon, pancit, and bibingka, as well as cooking methods like ginisa, pinakuluan, inihaw, and pinag-gisahan. The discussion may also reference Spanish, Chinese, and Malay "

model = stable_whisper.load_model('base', device='cuda')
result = model.transcribe(
    audio_file,
    initial_prompt = prompt,
    word_timestamps = False,
    vad = True,
    
    
    
))
result.to_srt_vtt('transcribed.srt')
